# %% [markdown]
# # Fisher-Kolmogorov–Petrovsky–Piskunov equation
# $\rho_t = r \rho(1−\rho) + D\partial^2_x \rho$

# %%
using PyPlot, Printf
using LinearAlgebra
using Flux, DiffEqFlux, Optim, DiffEqSensitivity
using BSON: @save, @load
using Flux: @epochs
using DifferentialEquations

# %%
save_folder = "data"
if isdir(save_folder)
else
    mkdir(save_folder)
end

# %%
# parameter
D = 0.01; # diffusion
r = 1.0; # reaction rate

# domain
X = 1.0;
T = 5;
dx = 0.04;
dt = T / 10;
x = collect(0:dx:X);
t = collect(0:dt:T);
Nx = Int64(X / dx + 1);
Nt = Int64(T / dt + 1);

# initial conditions
Amp = 1.0
Delta = 0.2
rho0 = Amp * (
        tanh.((x .- (0.5 - Delta / 2)) / (Delta / 10)) -
        tanh.((x .- (0.5 + Delta / 2)) / (Delta / 10))
    ) / 2;

# %%
close("all")
figure()
scatter(x, rho0)
title("Initial Condition")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1, 'Initial Condition')

# %% [markdown]
# ## Generate training data

# %%
reaction(u) = r * u .* (1 .- u)
lap = diagm(0 => -2.0 * ones(Nx), 1 => ones(Nx - 1), -1 => ones(Nx - 1)) ./ dx^2 # central difference matrix

# periodic BC
lap[1, end] = 1.0 / dx^2
lap[end, 1] = 1.0 / dx^2

rc_ode(rho, p, t) = reaction.(rho) + D * lap * rho

prob = ODEProblem(rc_ode, rho0, (0.0, T), saveat = dt)
sol = solve(prob, Tsit5());
ode_data = Array(sol);

# %%
subplot(121)
pcolor(x, t, ode_data')
xlabel("x");
ylabel("t");
colorbar()

subplot(122)
for i = 1:2:Nt
    plot(x, ode_data[:, i], label = "t=$(sol.t[i])")
end
xlabel("x");
ylabel(L"$\rho$");
legend(frameon = false, fontsize = 7, bbox_to_anchor = (1, 1), loc = "upper left", ncol = 1)
tight_layout()
savefig(@sprintf("%s/training_data.pdf", save_folder))
# Out:
# Figure(PyObject <Figure size 640x480 with 3 Axes>)

# %% [markdown]
# ## Define neural PDE

# %%
n_weights = 10

# for the reaction term
#rx_nn = Chain(
#    Dense(1, n_weights, tanh),
#    Dense(n_weights, 2 * n_weights, tanh),
#    Dense(2 * n_weights, n_weights, tanh),
#    Dense(n_weights, 1),
#    x -> x[1],
#)
rx_nn = Chain(
    Dense(1, 2 * n_weights, tanh),
    Dense(2 * n_weights, 2 * n_weights, tanh),
    Dense(2 * n_weights, 1),
    #x -> x[1],
)

# conv with bias with initial values as 1/dx^2
w_err = 0.0
init_w = reshape([1.1 -2.5 1.0], (3, 1, 1, 1))
diff_cnn_ = Conv(init_w, [0.0], pad = (0, 0, 0, 0))

# initialize D0 close to D/dx^2
D0 = [6.5]

p1, re1 = Flux.destructure(rx_nn)
p2, re2 = Flux.destructure(diff_cnn_)
p = [p1; p2; D0]
full_restructure(p) = re1(p[1:length(p1)]), re2(p[(length(p1)+1):end-1]), p[end]

function nn_ode(u, p, t)
    rx_nn = re1(p[1:length(p1)])

    # train a simple CNN: input 3, output 1
    # optimize a diagonal matrix for central difference
    u_cnn_1 = [p[end-4] * u[end] + p[end-3] * u[1] + p[end-2] * u[2]]
    u_cnn = [p[end-4] * u[i-1] + p[end-3] * u[i] + p[end-2] * u[i+1] for i = 2:Nx-1]
    u_cnn_end = [p[end-4] * u[end-1] + p[end-3] * u[end] + p[end-2] * u[1]]

    # Equivalent using Flux, but slower!
    #CNN term with periodic BC
    #diff_cnn_ = Conv(reshape(p[(end-4):(end-2)],(3,1,1,1)), [0.0], pad=(0,0,0,0))
    #u_cnn = reshape(diff_cnn_(reshape(u, (Nx, 1, 1, 1))), (Nx-2,))
    #u_cnn_1 = reshape(diff_cnn_(reshape(vcat(u[end:end], u[1:1], u[2:2]), (3, 1, 1, 1))), (1,))
    #u_cnn_end = reshape(diff_cnn_(reshape(vcat(u[end-1:end-1], u[end:end], u[1:1]), (3, 1, 1, 1))), (1,))

    [rx_nn([u[i]])[1] for i = 1:Nx] + 
    p[end] * vcat(u_cnn_1, u_cnn, u_cnn_end)
end
# Out:
# nn_ode (generic function with 1 method)

# %% [markdown]
# ## Define loss function

# %%
prob_nn = ODEProblem(nn_ode, rho0, (0.0, T), p)
sol_nn = solve(prob_nn, Tsit5(), u0 = rho0, p = p)

function predict_rd(θ)
    # No ReverseDiff if using Flux
    Array(concrete_solve(
        prob_nn,
        Tsit5(),
        rho0,
        θ,
        saveat = dt,
        sensealg = InterpolatingAdjoint(autojacvec = ReverseDiffVJP()),
    ))
end

#match data and force the weights of the CNN to add up to zero
function loss_rd(p)
    pred = predict_rd(p)
    sum(abs2, ode_data .- pred) + 10^2 * abs(sum(p[end-4:end-2])), pred
end
# Out:
# loss_rd (generic function with 1 method)

# %% [markdown]
# ## Train

# %%
opt = ADAM(0.001)

global count = 0
global save_count = 0
save_freq = 50

train_arr = Float64[]
diff_arr = Float64[]
w1_arr = Float64[]
w2_arr = Float64[]
w3_arr = Float64[]

# callback function to observe training
cb = function (p, l, pred)
    #=
    rx_nn, diff_cnn_, D0 = full_restructure(p)
    push!(train_arr, l)
    push!(diff_arr, p[end])

    weight = diff_cnn_.weight[:]
    push!(w1_arr, weight[1])
    push!(w2_arr, weight[2])
    push!(w3_arr, weight[3])

    println(@sprintf(
        "Loss: %0.4f\tD0: %0.4f Weights:(%0.4f,\t %0.4f, \t%0.4f) \t Sum: %0.4f" ,
        l,
        D0[1],
        weight[1],
        weight[2],
        weight[3],
        sum(weight)
    ))

    global count
    
    if count == 0
        fig = figure(figsize = (8, 2.5))
        ttl = fig.suptitle(@sprintf("Epoch = %d", count), y = 1.05)
        global ttl
        subplot(131)
        pcolormesh(x, t, ode_data')
        xlabel(L"$x$")
        ylabel(L"$t$")
        title("Data")
        colorbar()

        subplot(132)
        img = pcolormesh(x, t, pred')
        global img
        xlabel(L"$x$")
        ylabel(L"$t$")
        title("Prediction")
        colorbar()
        clim([0, 1])

        ax = subplot(133)
        global ax
        u = collect(0:0.01:1)
        rx_line = plot(u, rx_nn.([[elem] for elem in u]), label = "NN")[1]
        global rx_line
        plot(u, reaction.(u), label = "True")
        title("Reaction Term")
        legend(loc = "upper right", frameon = false, fontsize = 8)
        ylim([0, r * 0.25 + 0.2])

        subplots_adjust(top = 0.8)
        tight_layout()
    end

    if count > 0
        println("updating figure")
        img.set_array(pred[1:end-1, 1:end-1][:])
        ttl.set_text(@sprintf("Epoch = %d", count))

        u = collect(0:0.01:1)
        rx_pred = rx_nn.([[elem] for elem in u])
        rx_line.set_ydata(rx_pred)
        u = collect(0:0.01:1)

        min_lim = min(minimum(rx_pred), minimum(reaction.(u))) - 0.1
        max_lim = max(maximum(rx_pred), maximum(reaction.(u))) + 0.1

        ax.set_ylim([min_lim, max_lim])
    end

    global save_count
    if count % save_freq == 0
        println("saved figure")
        savefig(
            @sprintf("%s/pred_%05d.png", save_folder, save_count),
            dpi = 200,
            bbox_inches = "tight",
        )
        save_count += 1
    end

    display(gcf())
    count += 1
    =#
    false
end
# Out:
# #37 (generic function with 1 method)

# %%
res = DiffEqFlux.sciml_train(loss_rd, p, ADAM(), cb = cb, maxiters = 100)
# Out:
# loss: 26.5: 100%|█████████████████████████████████████████| Time: 0:02:02
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     2.647293e+01
#
#  * Found with
#     Algorithm:     ADAM
#
#  * Convergence measures
#     |x - x'|               = NaN ≰ 0.0e+00
#     |x - x'|/|x'|          = NaN ≰ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 0.0e+00
#
#  * Work counters
#     Seconds run:   124  (vs limit Inf)
#     Iterations:    100
#     f(x) calls:    100
#     ∇f(x) calls:   100

# %%
res = DiffEqFlux.sciml_train(loss_rd, res.minimizer, ADAM(0.001), cb = cb, maxiters = 200)
# Out:
# loss: 1.16: 100%|█████████████████████████████████████████| Time: 0:04:36
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.164252e+00
#
#  * Found with
#     Algorithm:     ADAM
#
#  * Convergence measures
#     |x - x'|               = NaN ≰ 0.0e+00
#     |x - x'|/|x'|          = NaN ≰ 0.0e+00
#     |f(x) - f(x')|         = NaN ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = NaN ≰ 0.0e+00
#     |g(x)|                 = NaN ≰ 0.0e+00
#
#  * Work counters
#     Seconds run:   277  (vs limit Inf)
#     Iterations:    200
#     f(x) calls:    200
#     ∇f(x) calls:   200

# %%
res = DiffEqFlux.sciml_train(loss_rd, res.minimizer, LBFGS(), cb = cb, maxiters = 200)
# Out:
# ┌ Warning: Instability detected. Aborting
# └ @ DiffEqBase /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/integrator_interface.jl:349
# ┌ Warning: First function call produced NaNs. Exiting.
# └ @ OrdinaryDiffEq /home/vavrines/.julia/packages/OrdinaryDiffEq/tVsYE/src/initdt.jl:76
# ┌ Warning: Automatic dt set the starting dt as NaN, causing instability.
# └ @ OrdinaryDiffEq /home/vavrines/.julia/packages/OrdinaryDiffEq/tVsYE/src/solve.jl:456
# ┌ Warning: NaN dt detected. Likely a NaN value in the state, parameters, or derivative value caused this outcome.
# └ @ DiffEqBase /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/integrator_interface.jl:323
# ┌ Warning: Instability detected. Aborting
# └ @ DiffEqBase /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/integrator_interface.jl:349
# ┌ Warning: First function call produced NaNs. Exiting.
# └ @ OrdinaryDiffEq /home/vavrines/.julia/packages/OrdinaryDiffEq/tVsYE/src/initdt.jl:76
# ┌ Warning: Automatic dt set the starting dt as NaN, causing instability.
# └ @ OrdinaryDiffEq /home/vavrines/.julia/packages/OrdinaryDiffEq/tVsYE/src/solve.jl:456
# ┌ Warning: NaN dt detected. Likely a NaN value in the state, parameters, or derivative value caused this outcome.
# └ @ DiffEqBase /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/integrator_interface.jl:323
# InterruptException:
#
# Stacktrace:
#  [1] _methods_by_ftype at ./reflection.jl:841 [inlined]
#  [2] _methods_by_ftype(::Any, ::Int64, ::UInt64) at ./reflection.jl:838
#  [3] _methods at ./reflection.jl:834 [inlined]
#  [4] return_type(::Any, ::Any, ::UInt64) at ./compiler/typeinfer.jl:641
#  [5] return_type(::Any, ::Any) at ./compiler/typeinfer.jl:627
#  [6] copy(::Base.Broadcast.Broadcasted{ReverseDiff.TrackedStyle,Tuple{Base.OneTo{Int64}},typeof(tanh),Tuple{Base.Broadcast.Broadcasted{ReverseDiff.TrackedStyle,Nothing,typeof(+),Tuple{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}}}}}) at /home/vavrines/.julia/packages/ReverseDiff/tCOFA/src/derivatives/broadcast.jl:91
#  [7] materialize at ./broadcast.jl:820 [inlined]
#  [8] Dense at /home/vavrines/.julia/packages/Flux/Fj3bt/src/layers/basic.jl:122 [inlined]
#  [9] applychain(::Tuple{Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(identity),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},var"#29#30"}, ::ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}) at /home/vavrines/.julia/packages/Flux/Fj3bt/src/layers/basic.jl:36 (repeats 2 times)
#  [10] Chain at /home/vavrines/.julia/packages/Flux/Fj3bt/src/layers/basic.jl:38 [inlined]
#  [11] (::var"#32#34"{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},Chain{Tuple{Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(identity),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},var"#29#30"}}})(::Int64) at ./none:0
#  [12] iterate at ./generator.jl:47 [inlined]
#  [13] collect_to!(::Array{ReverseDiff.TrackedReal{Float64,Float64,ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},1}, ::Base.Generator{UnitRange{Int64},var"#32#34"{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},Chain{Tuple{Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(identity),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},var"#29#30"}}}}, ::Int64, ::Int64) at ./array.jl:711
#  [14] collect_to_with_first!(::Array{ReverseDiff.TrackedReal{Float64,Float64,ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},1}, ::ReverseDiff.TrackedReal{Float64,Float64,ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}}, ::Base.Generator{UnitRange{Int64},var"#32#34"{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},Chain{Tuple{Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(identity),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},var"#29#30"}}}}, ::Int64) at ./array.jl:689
#  [15] collect(::Base.Generator{UnitRange{Int64},var"#32#34"{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},Chain{Tuple{Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(tanh),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Dense{typeof(identity),ReverseDiff.TrackedArray{Float64,Float64,2,Array{Float64,2},Array{Float64,2}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},var"#29#30"}}}}) at ./array.jl:670
#  [16] nn_ode(::ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}, ::ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}, ::ReverseDiff.TrackedReal{Float64,Float64,ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}}) at ./In[48]:45
#  [17] ODEFunction at /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/diffeqfunction.jl:248 [inlined]
#  [18] (::DiffEqSensitivity.var"#26#28"{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}})(::ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}, ::ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}, ::ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}) at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/derivative_wrappers.jl:235
#  [19] ReverseDiff.GradientTape(::Function, ::Tuple{Array{Float64,1},Array{Float64,1},Array{Float64,1}}, ::ReverseDiff.GradientConfig{Tuple{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}}}) at /home/vavrines/.julia/packages/ReverseDiff/tCOFA/src/api/tape.jl:207
#  [20] GradientTape at /home/vavrines/.julia/packages/ReverseDiff/tCOFA/src/api/tape.jl:204 [inlined]
#  [21] _vecjacobian!(::SubArray{Float64,1,Array{Float64,1},Tuple{UnitRange{Int64}},true}, ::Array{Float64,1}, ::SubArray{Float64,1,Array{Float64,1},Tuple{UnitRange{Int64}},true}, ::Array{Float64,1}, ::Float64, ::DiffEqSensitivity.ODEInterpolatingAdjointSensitivityFunction{DiffEqSensitivity.AdjointDiffCache{Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,ReverseDiff.GradientTape{DiffEqSensitivity.var"#78#87"{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},Tuple{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Nothing,Nothing,Nothing,Nothing,Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool}},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Array{Float64,1},ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats},Nothing,ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}}, ::ReverseDiffVJP{false}, ::SubArray{Float64,1,Array{Float64,1},Tuple{UnitRange{Int64}},true}, ::Nothing) at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/derivative_wrappers.jl:234
#  [22] #vecjacobian!#20 at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/derivative_wrappers.jl:147 [inlined]
#  [23] (::DiffEqSensitivity.ODEInterpolatingAdjointSensitivityFunction{DiffEqSensitivity.AdjointDiffCache{Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,ReverseDiff.GradientTape{DiffEqSensitivity.var"#78#87"{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},Tuple{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Nothing,Nothing,Nothing,Nothing,Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool}},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Array{Float64,1},ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats},Nothing,ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}})(::Array{Float64,1}, ::Array{Float64,1}, ::Array{Float64,1}, ::Float64) at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/interpolating_adjoint.jl:137
#  [24] ODEFunction at /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/diffeqfunction.jl:248 [inlined]
#  [25] perform_step!(::OrdinaryDiffEq.ODEIntegrator{Tsit5,true,Array{Float64,1},Nothing,Float64,Array{Float64,1},Float64,Float64,Float64,Array{Array{Float64,1},1},ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqSensitivity.ODEInterpolatingAdjointSensitivityFunction{DiffEqSensitivity.AdjointDiffCache{Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,ReverseDiff.GradientTape{DiffEqSensitivity.var"#78#87"{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},Tuple{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Nothing,Nothing,Nothing,Nothing,Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool}},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Array{Float64,1},ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats},Nothing,ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,CallbackSet{Tuple{},Tuple{DiscreteCallback{DiffEqCallbacks.var"#33#38"{Base.RefValue{Union{Nothing, Float64}}},DiffEqCallbacks.var"#34#39"{DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},DiffEqSensitivity.var"#95#97"{DiffEqSensitivity.var"#df#134"{Array{Float64,2},Array{Float64,1},Colon},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool},Bool,Nothing,Nothing,Nothing,Nothing,Bool,Array{Float64,1},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},Array{Float64,1},Base.RefValue{Int64},Int64,UniformScaling{Bool}},Base.RefValue{Union{Nothing, Float64}}},DiffEqCallbacks.var"#35#40"{Bool,DiffEqCallbacks.var"#37#42"{Bool},DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},Base.RefValue{Union{Nothing, Float64}},DiffEqCallbacks.var"#34#39"{DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},DiffEqSensitivity.var"#95#97"{DiffEqSensitivity.var"#df#134"{Array{Float64,2},Array{Float64,1},Colon},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Base.OneTo{Int64},UnitRange{Int64},UniformS ...
#  [26] perform_step! at /home/vavrines/.julia/packages/OrdinaryDiffEq/tVsYE/src/perform_step/low_order_rk_perform_step.jl:628 [inlined]
#  [27] solve!(::OrdinaryDiffEq.ODEIntegrator{Tsit5,true,Array{Float64,1},Nothing,Float64,Array{Float64,1},Float64,Float64,Float64,Array{Array{Float64,1},1},ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqSensitivity.ODEInterpolatingAdjointSensitivityFunction{DiffEqSensitivity.AdjointDiffCache{Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,ReverseDiff.GradientTape{DiffEqSensitivity.var"#78#87"{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},Tuple{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Nothing,Nothing,Nothing,Nothing,Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool}},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Array{Float64,1},ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats},Nothing,ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,CallbackSet{Tuple{},Tuple{DiscreteCallback{DiffEqCallbacks.var"#33#38"{Base.RefValue{Union{Nothing, Float64}}},DiffEqCallbacks.var"#34#39"{DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},DiffEqSensitivity.var"#95#97"{DiffEqSensitivity.var"#df#134"{Array{Float64,2},Array{Float64,1},Colon},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool},Bool,Nothing,Nothing,Nothing,Nothing,Bool,Array{Float64,1},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},Array{Float64,1},Base.RefValue{Int64},Int64,UniformScaling{Bool}},Base.RefValue{Union{Nothing, Float64}}},DiffEqCallbacks.var"#35#40"{Bool,DiffEqCallbacks.var"#37#42"{Bool},DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},Base.RefValue{Union{Nothing, Float64}},DiffEqCallbacks.var"#34#39"{DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},DiffEqSensitivity.var"#95#97"{DiffEqSensitivity.var"#df#134"{Array{Float64,2},Array{Float64,1},Colon},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Base.OneTo{Int64},UnitRange{Int64},UniformScaling{ ...
#  [28] #__solve#379 at /home/vavrines/.julia/packages/OrdinaryDiffEq/tVsYE/src/solve.jl:5 [inlined]
#  [29] solve_call(::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,Array{Float64,1},ODEFunction{true,DiffEqSensitivity.ODEInterpolatingAdjointSensitivityFunction{DiffEqSensitivity.AdjointDiffCache{Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,ReverseDiff.GradientTape{DiffEqSensitivity.var"#78#87"{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},Tuple{ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},ReverseDiff.TrackedArray{Float64,Float64,1,Array{Float64,1},Array{Float64,1}}},Nothing,Nothing,Nothing,Nothing,Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool}},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Array{Float64,1},ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats},Nothing,ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing}},UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Symbol,CallbackSet{Tuple{},Tuple{DiscreteCallback{DiffEqCallbacks.var"#33#38"{Base.RefValue{Union{Nothing, Float64}}},DiffEqCallbacks.var"#34#39"{DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},DiffEqSensitivity.var"#95#97"{DiffEqSensitivity.var"#df#134"{Array{Float64,2},Array{Float64,1},Colon},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool},Bool,Nothing,Nothing,Nothing,Nothing,Bool,Array{Float64,1},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},Array{Float64,1},Base.RefValue{Int64},Int64,UniformScaling{Bool}},Base.RefValue{Union{Nothing, Float64}}},DiffEqCallbacks.var"#35#40"{Bool,DiffEqCallbacks.var"#37#42"{Bool},DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},Base.RefValue{Union{Nothing, Float64}},DiffEqCallbacks.var"#34#39"{DiffEqSensitivity.var"#94#96"{Base.RefValue{Int64},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}},DiffEqSensitivity.var"#95#97"{DiffEqSensitivity.var"#df#134"{Array{Float64,2},Array{Float64,1},Colon},InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Base.OneTo{Int64},UnitRange{Int64},UniformScaling{Bool},Bool,Nothing,Nothing,Nothing,Nothing,Bool,Array{Float64,1},StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},Array{Float64,1},Base.RefValue{Int64},Int64,UniformScaling{Bool}},Base.RefValue{Union{Nothing, Float64}}}}} ...
#  [30] #solve_up#459 at /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/solve.jl:114 [inlined]
#  [31] #solve#458 at /home/vavrines/.julia/packages/DiffEqBase/ytJuW/src/solve.jl:102 [inlined]
#  [32] _adjoint_sensitivities(::ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats}, ::InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool}, ::Tsit5, ::DiffEqSensitivity.var"#df#134"{Array{Float64,2},Array{Float64,1},Colon}, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Nothing; abstol::Float64, reltol::Float64, checkpoints::Array{Float64,1}, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/sensitivity_interface.jl:22
#  [33] _adjoint_sensitivities(::ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats}, ::InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool}, ::Tsit5, ::Function, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}, ::Nothing) at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/sensitivity_interface.jl:13 (repeats 2 times)
#  [34] adjoint_sensitivities(::ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},false,Array{Float64,1},ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},DiffEqBase.StandardODEProblem},Tsit5,OrdinaryDiffEq.InterpolationData{ODEFunction{false,typeof(nn_ode),UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},DiffEqBase.DEStats}, ::Tsit5, ::Vararg{Any,N} where N; sensealg::InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool}, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/sensitivity_interface.jl:6
#  [35] (::DiffEqSensitivity.var"#adjoint_sensitivity_backpass#133"{Tsit5,InterpolatingAdjoint{0,true,Val{:central},ReverseDiffVJP{false},Bool},Array{Float64,1},Array{Float64,1},Tuple{},Colon})(::Array{Float64,2}) at /home/vavrines/.julia/packages/DiffEqSensitivity/oMkN7/src/local_sensitivity/concrete_solve.jl:127
#  [36] #529#back at /home/vavrines/.julia/packages/ZygoteRules/6nssF/src/adjoint.jl:55 [inlined]
#  [37] predict_rd at ./In[49]:6 [inlined]
#  [38] (::typeof(∂(predict_rd)))(::Array{Float64,2}) at /home/vavrines/.julia/packages/Zygote/YeCEW/src/compiler/interface2.jl:0
#  [39] loss_rd at ./In[49]:18 [inlined]
#  [40] (::typeof(∂(loss_rd)))(::Tuple{Int64,Nothing}) at /home/vavrines/.julia/packages/Zygote/YeCEW/src/compiler/interface2.jl:0
#  [41] #174 at /home/vavrines/.julia/packages/Zygote/YeCEW/src/lib/lib.jl:182 [inlined]
#  [42] (::Zygote.var"#347#back#176"{Zygote.var"#174#175"{typeof(∂(loss_rd)),Tuple{Tuple{Nothing},Int64}}})(::Tuple{Int64,Nothing}) at /home/vavrines/.julia/packages/ZygoteRules/6nssF/src/adjoint.jl:49
#  [43] #43 at /home/vavrines/.julia/packages/DiffEqFlux/FZMwP/src/train.jl:176 [inlined]
#  [44] (::typeof(∂(λ)))(::Int64) at /home/vavrines/.julia/packages/Zygote/YeCEW/src/compiler/interface2.jl:0
#  [45] #36 at /home/vavrines/.julia/packages/Zygote/YeCEW/src/compiler/interface.jl:46 [inlined]
#  [46] (::DiffEqFlux.var"#46#59"{DiffEqFlux.var"#43#56"{typeof(loss_rd)}})(::Array{Float64,1}, ::Array{Float64,1}) at /home/vavrines/.julia/packages/DiffEqFlux/FZMwP/src/train.jl:199
#  [47] value_gradient!!(::TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}) at /home/vavrines/.julia/packages/NLSolversBase/mGaJg/src/interface.jl:82
#  [48] value_gradient!(::TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}) at /home/vavrines/.julia/packages/NLSolversBase/mGaJg/src/interface.jl:69
#  [49] value_gradient!(::Optim.ManifoldObjective{TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}}, ::Array{Float64,1}) at /home/vavrines/.julia/packages/Optim/TNmSw/src/Manifolds.jl:50
#  [50] (::LineSearches.var"#ϕdϕ#6"{Optim.ManifoldObjective{TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}},Array{Float64,1},Array{Float64,1},Array{Float64,1}})(::Float64) at /home/vavrines/.julia/packages/LineSearches/WrsMD/src/LineSearches.jl:84
#  [51] (::LineSearches.HagerZhang{Float64,Base.RefValue{Bool}})(::Function, ::LineSearches.var"#ϕdϕ#6"{Optim.ManifoldObjective{TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}},Array{Float64,1},Array{Float64,1},Array{Float64,1}}, ::Float64, ::Float64, ::Float64) at /home/vavrines/.julia/packages/LineSearches/WrsMD/src/hagerzhang.jl:146
#  [52] HagerZhang at /home/vavrines/.julia/packages/LineSearches/WrsMD/src/hagerzhang.jl:101 [inlined]
#  [53] perform_linesearch!(::Optim.LBFGSState{Array{Float64,1},Array{Array{Float64,1},1},Array{Array{Float64,1},1},Float64,Array{Float64,1}}, ::LBFGS{Nothing,LineSearches.InitialStatic{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Optim.var"#15#17"}, ::Optim.ManifoldObjective{TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}}) at /home/vavrines/.julia/packages/Optim/TNmSw/src/utilities/perform_linesearch.jl:56
#  [54] update_state!(::TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Optim.LBFGSState{Array{Float64,1},Array{Array{Float64,1},1},Array{Array{Float64,1},1},Float64,Array{Float64,1}}, ::LBFGS{Nothing,LineSearches.InitialStatic{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Optim.var"#15#17"}) at /home/vavrines/.julia/packages/Optim/TNmSw/src/multivariate/solvers/first_order/l_bfgs.jl:198
#  [55] optimize(::TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}, ::LBFGS{Nothing,LineSearches.InitialStatic{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Optim.var"#15#17"}, ::Optim.Options{Float64,DiffEqFlux.var"#_cb#55"{var"#37#38",Base.Iterators.Cycle{Tuple{DiffEqFlux.NullData}}}}, ::Optim.LBFGSState{Array{Float64,1},Array{Array{Float64,1},1},Array{Array{Float64,1},1},Float64,Array{Float64,1}}) at /home/vavrines/.julia/packages/Optim/TNmSw/src/multivariate/optimize/optimize.jl:57
#  [56] optimize(::TwiceDifferentiable{Float64,Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}, ::LBFGS{Nothing,LineSearches.InitialStatic{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Optim.var"#15#17"}, ::Optim.Options{Float64,DiffEqFlux.var"#_cb#55"{var"#37#38",Base.Iterators.Cycle{Tuple{DiffEqFlux.NullData}}}}) at /home/vavrines/.julia/packages/Optim/TNmSw/src/multivariate/optimize/optimize.jl:33
#  [57] sciml_train(::Function, ::Array{Float64,1}, ::LBFGS{Nothing,LineSearches.InitialStatic{Float64},LineSearches.HagerZhang{Float64,Base.RefValue{Bool}},Optim.var"#15#17"}, ::Base.Iterators.Cycle{Tuple{DiffEqFlux.NullData}}; cb::Function, maxiters::Int64, diffmode::DiffEqFlux.ZygoteDiffMode, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /home/vavrines/.julia/packages/DiffEqFlux/FZMwP/src/train.jl:269

# %%
pred = predict_rd(res.minimizer)
# Out:
# 26×11 Array{Float64,2}:
#  0.0          0.109     0.223528  0.345845  …  0.800958  0.847323  0.882677
#  2.22045e-16  0.109241  0.224593  0.345996     0.79904   0.845641  0.881686
#  1.26565e-14  0.110164  0.229226  0.351483     0.798092  0.844853  0.880778
#  6.91447e-13  0.112745  0.238599  0.36251      0.798863  0.844982  0.880847
#  3.77514e-11  0.119178  0.254568  0.379788     0.800911  0.846063  0.881226
#  2.06115e-9   0.133588  0.279312  0.403307  …  0.804208  0.847972  0.882358
#  1.12535e-7   0.162396  0.314712  0.433485     0.80876   0.850668  0.883914
#  6.14417e-6   0.213277  0.361363  0.468889     0.813827  0.853908  0.885866
#  0.00033535   0.291744  0.417901  0.508505     0.819815  0.857592  0.888215
#  0.0179862    0.395913  0.480118  0.548893     0.825491  0.861409  0.890553
#  0.5          0.512663  0.54167   0.587517  …  0.831522  0.86523   0.893134
#  0.982014     0.619167  0.594567  0.620049     0.836519  0.868746  0.895339
#  0.999659     0.690362  0.631303  0.643796     0.841201  0.871834  0.89754
#  0.999659     0.708228  0.646248  0.65583      0.844403  0.874251  0.899132
#  0.982014     0.668217  0.637078  0.655027     0.846661  0.87591   0.900435
#  0.5          0.580818  0.605332  0.64158   …  0.847364  0.876685  0.901076
#  0.0179862    0.467886  0.555884  0.616637     0.846675  0.876545  0.901169
#  0.00033535   0.354526  0.496099  0.583408     0.844739  0.875505  0.900737
#  6.14417e-6   0.25998   0.433704  0.544513     0.841242  0.873599  0.899577
#  1.12535e-7   0.192561  0.375674  0.504332     0.837117  0.870974  0.898189
#  2.06115e-9   0.15073   0.326527  0.465234  …  0.831588  0.86773   0.896017
#  3.77514e-11  0.127841  0.288368  0.430545     0.826215  0.864109  0.894004
#  6.91447e-13  0.116675  0.260983  0.401125     0.819897  0.86026   0.891292
#  1.26565e-14  0.111773  0.242789  0.378293     0.814513  0.856465  0.889129
#  2.22045e-16  0.109826  0.231681  0.361584     0.808837  0.852891  0.886476
#  0.0          0.109142  0.225707  0.35099   …  0.804696  0.849792  0.884679

# %%
subplot(121)
pcolormesh(x, t, ode_data')
xlabel(L"$x$")
ylabel(L"$t$")
title("Data")
colorbar()

subplot(122)
img = pcolormesh(x, t, pred')
xlabel(L"$x$")
ylabel(L"$t$")
title("Prediction")
colorbar()
#clim([0, 1])
# Out:
# Figure(PyObject <Figure size 640x480 with 4 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7fd2c86a9fd0>

# %%
import Plots
p1 = Plots.contourf(x, t, ode_data', label="Data")
p2 = Plots.contourf(x, t, pred', label="NN")
Plots.plot(p1, p2)
